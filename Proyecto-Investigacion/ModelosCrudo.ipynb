# %% [markdown]
# <a href="https://colab.research.google.com/github/24danielcr/inteligencia-artificial/blob/main/Proyecto-Investigacion/ModelosCrudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clasificacion de sonidos estridentes con espectrogramas
#
# **Integrantes:**
# - Christopher Víquez Aguilar - christopherviquezaguilar@gmail.com
# - Sebastian Arce Flores - sebasarc0224@hotmail.com

# %% [markdown]
# # Librerias y dependencias

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 588.9 kB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.4 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 82.9 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 23.9 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 117.4 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 112.0 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 125.3 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.6 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, google-pasta, tensorboard, astunparse, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.31.1
#     Uninstalling protobuf-6.31.1:
#       Successfully uninstalled protobuf-6.31.1
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 google-pasta-0.2.0 libclang-18.1.1 protobuf-5.29.5 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 werkzeug-3.1.3 wheel-0.45.1

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, GlobalAvgPool2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
import matplotlib.pyplot as plt
import random
import os
import glob
import requests
from collections import defaultdict

# %% [markdown]
# # Datos

# %% [markdown]
# ## Descarga de datos

# %%
def download_github_folder_recursive(owner, repo, folder_path, local_base_path, branch='main'):
    """
    Descarga recursivamente una carpeta completa de GitHub manteniendo la estructura
    """
    api_url = f"https://api.github.com/repos/{owner}/{repo}/contents/{folder_path}"

    try:
        response = requests.get(api_url)
        if response.status_code != 200:
            print(f"Error accessing {folder_path}: {response.status_code}")
            return

        items = response.json()

        # Crear directorio local si no existe
        local_folder_path = os.path.join(local_base_path, folder_path)
        os.makedirs(local_folder_path, exist_ok=True)

        for item in items:
            if item['type'] == 'file':
                # Descargar archivo
                file_url = f"https://raw.githubusercontent.com/{owner}/{repo}/{branch}/{folder_path}/{item['name']}"
                file_response = requests.get(file_url)

                if file_response.status_code == 200:
                    file_path = os.path.join(local_folder_path, item['name'])
                    with open(file_path, 'wb') as f:
                        f.write(file_response.content)
                    print(f"✓ Descargado: {folder_path}/{item['name']}")
                else:
                    print(f"✗ Error descargando: {folder_path}/{item['name']}")

            elif item['type'] == 'dir':
                # Llamada recursiva para subdirectorios
                subfolder_path = f"{folder_path}/{item['name']}" if folder_path else item['name']
                download_github_folder_recursive(owner, repo, subfolder_path, local_base_path, branch)

    except Exception as e:
        print(f"Error procesando {folder_path}: {str(e)}")

def download_sound_dataset_from_github(owner, repo, dataset_folder="Sounds-Processed", branch='main', local_path='/content'):
    """
    Descarga el dataset completo desde GitHub con la estructura:
    Sounds-Processed/
    ├── test/
    │   ├── Non-Strident/
    │   └── Strident/
    ├── train/
    │   ├── Non-Strident/
    │   └── Strident/
    └── val/
        ├── Non-Strident/
        └── Strident/
    """

    print(f"🔄 Descargando dataset desde GitHub: {owner}/{repo}")
    print(f"📁 Carpeta: {dataset_folder}")
    print("=" * 60)

    # Descargar toda la estructura recursivamente
    download_github_folder_recursive(owner, repo, dataset_folder, local_path, branch)

    print("\n✅ Descarga completada")
    return os.path.join(local_path, dataset_folder)

# %%
# Descargar datos desde GitHub
owner = "24danielcr"
repo = "inteligencia-artificial"
dataset_folder = "Proyecto-Investigacion/Espectrogramas/Sounds-Raw"
branch = "main"

local_dataset_path = download_sound_dataset_from_github(owner, repo, dataset_folder, branch)
# Out:
# 🔄 Descargando dataset desde GitHub: 24danielcr/inteligencia-artificial
# 📁 Carpeta: Proyecto-Investigacion/Espectrogramas/Sounds-Raw
# ============================================================
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/1-23094-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/17_11737_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/17_11739_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/17_11742_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/17_11744_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/17_11756_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/17_11758_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11842_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11851_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11852_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11860_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11865_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11866_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11870_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/18_11874_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/19_11935_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/19_11945_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/19_11958_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/19_11973_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/1_10151_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/1_10155_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/1_10158_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/2-64962-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/2-72547-D_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/23_12367_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/23_12371_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/23_12373_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/27_12717_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/27_12740_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/27_12751_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/3-129678-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/3-166324-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/4-182795-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/4-188293-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/4-223127-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/4_10439_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/5-216216-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/5-243448-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/5-243459-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/6_10641_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/6_10644_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/6_10647_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/6_10653_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/6_10661_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/6_10663_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0human171120_2140699-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0human179928_3223507-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0human44713_6281-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0human58407_43834-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0human80280_1123190-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0mechanical326631_5305165-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature125725_296888-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature139945_2352202-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature154999_130385-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature21842_18799-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature52877_283424-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature61388_806506-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature61620_222582-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature95258_1574595-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0nature97920_213393-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society142296_2576155-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society164344_18799-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society180911_1531809-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society22326_113722-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society49763_478853-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society62633_791247-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society73278_828209-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_0society74382_1035425-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_1human178333_2042115-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_1human54889_29541-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_1mechanical135063_658546-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Non-Strident/r_1mechanical163683_2843367-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-116765-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-172649-D_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-17367-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-20545-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-26806-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-28135-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-32373-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-43382-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-43807-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-44831-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-51035-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-64473-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-76831-D_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-88409-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/1-96950-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-102568-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-117615-E_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-117616-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-117625-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-132157-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-133863-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-141681-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-39441-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-50666-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-50667-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-57191-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-59321-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-70052-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-70938-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-7321-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-81731-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-93030-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/2-96460-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/254478__wjoojoo__marvie_screech4_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-111102-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-119120-E_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-124795-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-127890-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-128512-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-129264-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-136608-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-142006-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-143562-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-143929-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-151081-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-151557-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-152007-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-152020-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-156391-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-163288-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-180977-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-203371-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-96606-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/3-98869-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-102844-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-102871-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-119648-D_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-125929-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-145081-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-150364-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-160036-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-161105-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-164064-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-165606-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-167063-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-168446-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-172734-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-175000-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-177250-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-181999-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-184575-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-191015-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-199261-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-204121-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/4-218199-F_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-141683-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-151085-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-156999-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-160551-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-173568-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-179496-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-179865-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-182012-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-187444-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-188495-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-188716-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-188945-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-198411-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-198411-D_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-198411-E_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-198411-F_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-213077-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-216368-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-221528-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-238021-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/5-253094-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/551128__globofonia__metro-station-scalator-screech_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/556535__jvmykagmailcom__alien-screech_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/593819__timkahn__car-pass-with-rock-in-the-brakes_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/test/Strident/711450__lonerdroner__231027_0181-vacuum-cleaner-screech_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-100038-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-12653-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-12654-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-16746-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-23094-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-34495-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-34497-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-38559-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-38560-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-50623-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-54918-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-54918-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-57316-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-57318-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-59102-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-65483-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-7456-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-80840-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-80841-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-90797-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1-9841-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11736_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11738_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11740_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11741_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11743_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11745_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11746_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11747_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11748_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11749_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11750_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11751_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11752_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11753_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11754_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11755_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11757_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11759_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11761_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11762_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11763_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11764_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11765_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11766_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11767_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11768_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11770_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11771_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11772_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11773_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11774_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/17_11775_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11835_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11837_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11839_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11840_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11841_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11843_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11845_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11846_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11847_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11848_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11849_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11850_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11853_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11854_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11855_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11856_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11857_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11858_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11859_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11861_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11862_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11863_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11867_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11868_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11869_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11871_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11872_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/18_11873_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11936_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11937_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11938_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11939_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11940_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11941_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11942_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11944_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11946_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11947_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11949_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11950_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11951_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11952_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11953_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11954_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11955_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11956_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11957_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11959_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11960_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11961_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11962_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11963_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11964_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11965_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11966_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11967_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11968_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11969_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11970_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11971_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/19_11974_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10136_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10137_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10139_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10140_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10141_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10142_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10143_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10144_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10145_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10146_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10147_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10149_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10150_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10152_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10154_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10156_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10157_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10160_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10161_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10162_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10163_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10164_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10165_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10166_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10168_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10169_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10170_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10171_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10172_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10173_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/1_10175_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-106019-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-108760-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-108760-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-108761-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-110613-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-122616-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-124564-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-125821-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-125875-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-139748-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-139748-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-139749-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-64963-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-68595-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-68595-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-72547-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-72547-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-72547-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-80844-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-83270-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-85139-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/2-96033-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12351_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12352_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12353_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12354_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12355_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12356_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12358_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12365_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12366_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12368_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/23_12370_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12713_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12714_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12727_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12728_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12734_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12739_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12748_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12749_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12750_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12759_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12760_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12761_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12762_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12763_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12764_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12765_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12766_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12770_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/27_12772_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-129338-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-134802-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-155577-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-155578-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-155579-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-155583-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-155766-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-156581-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-156581-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-156907-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-160119-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-162786-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-163607-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-163607-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-164592-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-164593-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-164594-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/3-181132-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-163697-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-171823-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-172143-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-174797-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-181362-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-187769-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-187769-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-188293-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-194246-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-195707-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-195805-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-197871-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-202749-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-212604-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-212604-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-212604-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-216211-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4-223125-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10436_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10437_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10438_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10440_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10441_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10442_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10443_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10444_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10445_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10446_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10447_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10448_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10449_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10450_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10451_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10452_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10453_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10454_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10455_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10456_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10457_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10458_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10459_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10460_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10463_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10464_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10465_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10466_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10467_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10468_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10469_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10470_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10472_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10473_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10474_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/4_10475_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/5-204352-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/train/Non-Strident/5-204352-B_spectrogram.png
# ...
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/3-166326-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/4-159609-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/4-159609-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/4-168155-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/4_10461_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/4_10462_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/4_10471_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/6_10637_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/6_10662_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/6_10664_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/6_10668_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0human106568_7037-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0human117503_2101324-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0human125859_43-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0human22388_117199-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0human261596_4486188-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0human77372_1173265-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0human83360_791247-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0mechanical145013_2580450-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0mechanical244364_557477-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0mechanical264313_3820822-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0mechanical274257_4486188-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0mechanical47044_230160-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature118148_439521-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature121246_1658678-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature129336_2355772-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature15542_2-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature17535_17129-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature38895_94155-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature56522_36188-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0nature57889_695835-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society121787_2168040-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society152038_2753909-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society177543_612689-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society199687_1143716-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society27864_89943-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society35299_341440-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society41639_96-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society66604_800302-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society73610_649002-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society87065_339463-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_0society95843_1059930-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_1human44199_215874-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_1mechanical155610_2629425-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_1mechanical177779_2035780-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_4mechanical264850_4975383-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Non-Strident/r_6mechanical60455_27178-hq_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-115545-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-119125-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-13613-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-21189-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-23996-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-32318-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-39835-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-40730-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-43760-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-50060-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-51805-D_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-91359-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/1-9886-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-100648-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-100786-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-101676-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-102435-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-107351-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-108767-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-109371-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-110417-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-114280-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-117615-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-117615-D_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-122066-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-122820-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-135649-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-135860-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-138465-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-141563-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-141682-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-151079-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-160888-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-188822-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-205966-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-262579-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-39443-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-39945-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-51173-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-65750-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-70936-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-72688-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-77945-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-78562-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-81270-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/2-91912-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-117504-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-117793-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-123086-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-135650-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-139109-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-145577-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-148330-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-151557-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-152007-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-159347-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-164630-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-174840-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-182710-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-187710-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-251617-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-51731-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-51909-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/3-58772-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/382586__macdaddyno1__eerie-sounding-train-with-a-breaking-screech_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-107122-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-119648-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-125072-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-125072-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-161579-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-164064-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-167063-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-176638-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-178402-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-182395-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-183882-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-183882-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-185415-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-185575-C_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-193480-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-194680-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-195497-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-204777-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-209536-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-218199-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-218199-H_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-59579-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-80761-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/4-90014-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-161270-B_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-171653-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-177779-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-195557-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-197988-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-198600-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-216370-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-221518-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-242711-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/5-253101-A_spectrogram.png
# ✓ Descargado: Proyecto-Investigacion/Espectrogramas/Sounds-Raw/val/Strident/554502__c-v__train-horn-and-wheel-screeches_spectrogram.png
#
# ✅ Descarga completada

# %% [markdown]
# ## Carga del dataset

# %%
def load_dataset_structure(base_path):
    """Carga todos los archivos PNG organizados por conjunto y clase"""
    dataset = {
        'train': {'Non-Strident': [], 'Strident': []},
        'test': {'Non-Strident': [], 'Strident': []},
        'val': {'Non-Strident': [], 'Strident': []}
    }

    print("📊 Organizando archivos PNG del dataset...")
    print("=" * 40)

    total_files = 0

    for split in ['train', 'test', 'val']:
        for class_name in ['Non-Strident', 'Strident']:
            path = os.path.join(base_path, split, class_name)
            if os.path.exists(path):
                # Buscar específicamente archivos .png
                png_files = glob.glob(os.path.join(path, '*.png'))
                dataset[split][class_name] = png_files
                total_files += len(png_files)
                print(f"🖼️  {split}/{class_name}: {len(png_files)} imágenes PNG")
            else:
                print(f"⚠️  {split}/{class_name}: Carpeta no encontrada")

    print(f"\n🎯 Total de imágenes PNG cargadas: {total_files}")
    return dataset

def get_dataset_summary(dataset):
    """Muestra un resumen del dataset cargado"""
    print("\n📈 RESUMEN DEL DATASET")
    print("=" * 50)

    for split in ['train', 'test', 'val']:
        total_split = sum(len(files) for files in dataset[split].values())
        non_strident_count = len(dataset[split]['Non-Strident'])
        strident_count = len(dataset[split]['Strident'])

        print(f"\n{split.upper()}:")
        print(f"  • Total: {total_split} archivos")
        print(f"  • Non-Strident: {non_strident_count}")
        print(f"  • Strident: {strident_count}")

        if total_split > 0:
            balance = min(non_strident_count, strident_count) / max(non_strident_count, strident_count) * 100
            print(f"  • Balance de clases: {balance:.1f}%")

def load_and_display_sample_images(dataset, split='train', samples_per_class=3):
    """
    Carga y muestra imágenes de muestra del dataset
    """
    import matplotlib.pyplot as plt
    from PIL import Image

    fig, axes = plt.subplots(2, samples_per_class, figsize=(15, 8))
    fig.suptitle(f'Muestras del conjunto {split.upper()}', fontsize=16)

    classes = ['Non-Strident', 'Strident']

    for i, class_name in enumerate(classes):
        images = dataset[split][class_name][:samples_per_class]

        for j, img_path in enumerate(images):
            try:
                img = Image.open(img_path)
                axes[i, j].imshow(img)
                axes[i, j].set_title(f'{class_name}\n{os.path.basename(img_path)}')
                axes[i, j].axis('off')
            except Exception as e:
                axes[i, j].text(0.5, 0.5, f'Error:\n{str(e)}',
                               ha='center', va='center', transform=axes[i, j].transAxes)
                axes[i, j].axis('off')

    plt.tight_layout()
    plt.show()

def get_image_info(dataset):
    """
    Obtiene información sobre las dimensiones de las imágenes
    """
    from PIL import Image

    print("🖼️  INFORMACIÓN DE IMÁGENES")
    print("=" * 50)

    for split in ['train', 'test', 'val']:
        print(f"\n{split.upper()}:")

        for class_name in ['Non-Strident', 'Strident']:
            images = dataset[split][class_name]
            if images:
                # Tomar una muestra para analizar dimensiones
                sample_size = min(5, len(images))
                dimensions = []

                for img_path in images[:sample_size]:
                    try:
                        with Image.open(img_path) as img:
                            dimensions.append(img.size)  # (width, height)
                    except:
                        continue

                if dimensions:
                    widths = [d[0] for d in dimensions]
                    heights = [d[1] for d in dimensions]

                    print(f"  {class_name}:")
                    print(f"    • Archivos: {len(images)}")
                    print(f"    • Dimensiones promedio: {sum(widths)//len(widths)}x{sum(heights)//len(heights)}")
                    print(f"    • Rango ancho: {min(widths)}-{max(widths)}px")
                    print(f"    • Rango alto: {min(heights)}-{max(heights)}px")

# %%
# Organizar archivos
local_dataset_path = "Proyecto-Investigacion/Espectrogramas/Sounds-Raw"
dataset = load_dataset_structure(local_dataset_path)
# Out:
# 📊 Organizando archivos PNG del dataset...
# ========================================
# 🖼️  train/Non-Strident: 581 imágenes PNG
# 🖼️  train/Strident: 800 imágenes PNG
# 🖼️  test/Non-Strident: 72 imágenes PNG
# 🖼️  test/Strident: 100 imágenes PNG
# 🖼️  val/Non-Strident: 72 imágenes PNG
# 🖼️  val/Strident: 100 imágenes PNG
#
# 🎯 Total de imágenes PNG cargadas: 1725

# %%
# Mostrar resumen
get_dataset_summary(dataset)
# Out:
# 📈 RESUMEN DEL DATASET
# ==================================================
#
# TRAIN:
#   • Total: 1381 archivos
#   • Non-Strident: 581
#   • Strident: 800
#   • Balance de clases: 72.6%
#
# TEST:
#   • Total: 172 archivos
#   • Non-Strident: 72
#   • Strident: 100
#   • Balance de clases: 72.0%
#
# VAL:
#   • Total: 172 archivos
#   • Non-Strident: 72
#   • Strident: 100
#   • Balance de clases: 72.0%

# %%
# Ver información de las imágenes
get_image_info(dataset)
# Out:
# 🖼️  INFORMACIÓN DE IMÁGENES
# ==================================================
#
# TRAIN:
#   Non-Strident:
#     • Archivos: 581
#     • Dimensiones promedio: 500x200
#     • Rango ancho: 500-500px
#     • Rango alto: 200-200px
#   Strident:
#     • Archivos: 800
#     • Dimensiones promedio: 500x200
#     • Rango ancho: 500-500px
#     • Rango alto: 200-200px
#
# TEST:
#   Non-Strident:
#     • Archivos: 72
#     • Dimensiones promedio: 500x200
#     • Rango ancho: 500-500px
#     • Rango alto: 200-200px
#   Strident:
#     • Archivos: 100
#     • Dimensiones promedio: 500x200
#     • Rango ancho: 500-500px
#     • Rango alto: 200-200px
#
# VAL:
#   Non-Strident:
#     • Archivos: 72
#     • Dimensiones promedio: 500x200
#     • Rango ancho: 500-500px
#     • Rango alto: 200-200px
#   Strident:
#     • Archivos: 100
#     • Dimensiones promedio: 500x200
#     • Rango ancho: 500-500px
#     • Rango alto: 200-200px

# %%
# Mostrar imágenes de muestra
load_and_display_sample_images(dataset, split='train', samples_per_class=3)

# %% [markdown]
# ## Preprocess dataset

# %%
def load_images_as_arrays(dataset, split='train', max_per_class=None, target_size=(500, 200)):
    """
    Carga las imágenes como arrays de numpy para machine learning,
    redimensionando a un tamaño objetivo.
    """
    import numpy as np
    from PIL import Image

    X = []  # imágenes
    y = []  # etiquetas
    filenames = []

    classes = ['Non-Strident', 'Strident']

    print(f"Cargando imágenes del conjunto {split.upper()} y redimensionando a {target_size}...")

    for i, class_name in enumerate(classes):
        images = dataset[split][class_name]

        if max_per_class:
            images = images[:max_per_class]

        print(f"  Cargando {len(images)} imágenes de {class_name}...")

        for img_path in images:
            try:
                with Image.open(img_path) as img:
                    # Convertir a RGB si es necesario
                    if img.mode != 'RGB':
                        img = img.convert('RGB')

                    # Redimensionar imagen
                    img_resized = img.resize(target_size)

                    # Convertir a array
                    img_array = np.array(img_resized)

                    X.append(img_array)
                    y.append(i)  # 0 para Non-Strident, 1 para Strident
                    filenames.append(os.path.basename(img_path))

            except Exception as e:
                print(f"Error cargando {img_path}: {e}")

    X = np.array(X)
    y = np.array(y)

    print(f"✅ Cargadas {len(X)} imágenes con forma {X.shape}")
    return X, y, filenames

# %%
# 5. Cargar imágenes como arrays para machine learning
X_train, y_train, train_names = load_images_as_arrays(dataset, 'train')
X_test, y_test, test_names = load_images_as_arrays(dataset, 'test')
X_val, y_val, val_names = load_images_as_arrays(dataset, 'val')

print(f"Forma de datos de entrenamiento: {X_train.shape}")
print(f"Etiquetas de entrenamiento: {y_train.shape}")
# Out:
# Cargando imágenes del conjunto TRAIN y redimensionando a (500, 200)...
#   Cargando 581 imágenes de Non-Strident...
#   Cargando 800 imágenes de Strident...
# ✅ Cargadas 1381 imágenes con forma (1381, 200, 500, 3)
# Cargando imágenes del conjunto TEST y redimensionando a (500, 200)...
#   Cargando 72 imágenes de Non-Strident...
#   Cargando 100 imágenes de Strident...
# ✅ Cargadas 172 imágenes con forma (172, 200, 500, 3)
# Cargando imágenes del conjunto VAL y redimensionando a (500, 200)...
#   Cargando 72 imágenes de Non-Strident...
#   Cargando 100 imágenes de Strident...
# ✅ Cargadas 172 imágenes con forma (172, 200, 500, 3)
# Forma de datos de entrenamiento: (1381, 200, 500, 3)
# Etiquetas de entrenamiento: (1381,)

# %%
# 2. PREPROCESAMIENTO DE DATOS
def preprocess_data(X_train, X_test, X_val):
    """
    Preprocesa los datos para entrenamiento
    """
    print("🔧 Preprocesando datos...")

    # Normalizar píxeles (0-255 -> 0-1)
    X_train = X_train.astype('float32') / 255.0
    X_test = X_test.astype('float32') / 255.0
    X_val = X_val.astype('float32') / 255.0


    print(f"✅ Datos preprocesados:")
    print(f"   Training: {X_train.shape}")
    print(f"   Test: {X_test.shape}")
    print(f"   Validation: {X_val.shape}")

    return X_train, X_test, X_val

# %%
X_train, X_test, X_val = preprocess_data(X_train, X_test, X_val)
# Out:
# 🔧 Preprocesando datos...
# ✅ Datos preprocesados:
#    Training: (1381, 200, 500, 3)
#    Test: (172, 200, 500, 3)
#    Validation: (172, 200, 500, 3)

# %%
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)

# %% [markdown]
# # CNN model

# %% [markdown]
# ## Arquitectura

# %%
# CREAR EL MODELO (con input_shape correcto)
def create_cnn_model(input_shape):
    """
    Crea el modelo CNN con la forma de entrada correcta
    """
    print(f"🏗️  Creando modelo CNN con input_shape: {input_shape}")

    model = Sequential()

    # Primera capa convolucional
    model.add(Conv2D(16, (3, 3), activation='relu', input_shape=input_shape))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

    # Segunda capa convolucional
    model.add(Conv2D(32, (3, 3), activation='relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

    # Tercera capa convolucional
    model.add(Conv2D(64, (3, 3), activation='relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

    # Pooling
    model.add(GlobalAvgPool2D())
    #model.add(Dropout(0.25))

    # Capas densas
    #model.add(Flatten())
    #model.add(Dense(128, activation='relu'))
    #model.add(BatchNormalization())
    #model.add(Dropout(0.5))

    model.add(Dense(64, activation='relu'))

    # Salida
    model.add(Dense(2, activation='softmax'))  # 2 clases: Non-Strident y Strident

    # Compilar modelo
    model.compile(
        loss='categorical_crossentropy',
        optimizer='rmsprop',
        metrics=['accuracy']
    )

    return model

# %%
input_shape = X_train.shape[1:]

model = create_cnn_model(input_shape)

# Mostrar resumen del modelo
print("\n📋 Resumen del modelo:")
model.summary()
# Out:
# 🏗️  Creando modelo CNN con input_shape: (200, 500, 3)
#
# 📋 Resumen del modelo:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 198, 498, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 99, 249, 16)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 97, 247, 32)    │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 123, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 46, 121, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 23, 60, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,874 (108.88 KB)
#  Trainable params: 27,874 (108.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training

# %%
# CONFIGURAR CALLBACKS
def setup_callbacks():
    """
    Configura los callbacks para el entrenamiento
    """
    earlystop = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    learning_rate_reduction = ReduceLROnPlateau(
        monitor='val_accuracy',  # Cambiado de 'val_acc' a 'val_accuracy'
        patience=3,
        verbose=1,
        factor=0.5,
        min_lr=0.00001
    )

    return [earlystop] # [earlystop, learning_rate_reduction]

# FUNCIÓN PRINCIPAL DE ENTRENAMIENTO
def train_model(model, X_train, y_train, X_val, y_val,
                epochs=50, batch_size=32, verbose=1):
    """
    Entrena el modelo CNN completo
    """
    print("🚀 Iniciando entrenamiento del modelo...")
    print("=" * 60)

    # Configurar callbacks
    callbacks = setup_callbacks()

    # Entrenar modelo
    print(f"\n🎯 Entrenando por {epochs} épocas...")
    history = model.fit(
        X_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(X_val, y_val),
        callbacks=callbacks,
        verbose=verbose
    )

    # Evaluar en conjunto de prueba
    print("\n📊 Evaluando en conjunto de prueba...")
    test_loss, test_accuracy = model.evaluate(X_val, y_val, verbose=0)
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

    return history

# FUNCIÓN PARA VISUALIZAR RESULTADOS
def plot_training_history(history):
    """
    Visualiza la historia del entrenamiento
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # Accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)

    # Loss
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

# %%
# Entrenar el modelo (esto ejecutará todo el pipeline)
history = train_model(model, X_train, y_train, X_val, y_val,
                            epochs=100, batch_size=64)
# Out:
# 🚀 Iniciando entrenamiento del modelo...
# ============================================================
#
# 🎯 Entrenando por 100 épocas...
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.5621 - loss: 0.6859 - val_accuracy: 0.4942 - val_loss: 0.6915
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.5449 - loss: 0.6806 - val_accuracy: 0.5814 - val_loss: 0.6706
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.5955 - loss: 0.6508 - val_accuracy: 0.5581 - val_loss: 0.6660
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6316 - loss: 0.6535 - val_accuracy: 0.5523 - val_loss: 0.6673
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6269 - loss: 0.6369 - val_accuracy: 0.6453 - val_loss: 0.6554
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6475 - loss: 0.6252 - val_accuracy: 0.6628 - val_loss: 0.6441
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6314 - loss: 0.6385 - val_accuracy: 0.6570 - val_loss: 0.6451
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6199 - loss: 0.6539 - val_accuracy: 0.6047 - val_loss: 0.6507
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6507 - loss: 0.6313 - val_accuracy: 0.5814 - val_loss: 0.6494
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6475 - loss: 0.6204 - val_accuracy: 0.5930 - val_loss: 0.6415
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6526 - loss: 0.6125 - val_accuracy: 0.6512 - val_loss: 0.6085
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6882 - loss: 0.6060 - val_accuracy: 0.6860 - val_loss: 0.5994
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6975 - loss: 0.5819 - val_accuracy: 0.6744 - val_loss: 0.5963
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6926 - loss: 0.5821 - val_accuracy: 0.6686 - val_loss: 0.5830
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6702 - loss: 0.6002 - val_accuracy: 0.5930 - val_loss: 0.5975
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6782 - loss: 0.5795 - val_accuracy: 0.5756 - val_loss: 0.6107
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6933 - loss: 0.5772 - val_accuracy: 0.6570 - val_loss: 0.5560
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6897 - loss: 0.5830 - val_accuracy: 0.6395 - val_loss: 0.5714
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7082 - loss: 0.5674 - val_accuracy: 0.6919 - val_loss: 0.5623
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6918 - loss: 0.5668 - val_accuracy: 0.6919 - val_loss: 0.5525
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6712 - loss: 0.5802 - val_accuracy: 0.6977 - val_loss: 0.5894
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6905 - loss: 0.5547 - val_accuracy: 0.7093 - val_loss: 0.5519
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6847 - loss: 0.5816 - val_accuracy: 0.6802 - val_loss: 0.5394
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6834 - loss: 0.5584 - val_accuracy: 0.6919 - val_loss: 0.5396
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6846 - loss: 0.5781 - val_accuracy: 0.7151 - val_loss: 0.5281
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7101 - loss: 0.5501 - val_accuracy: 0.6570 - val_loss: 0.5472
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6934 - loss: 0.5509 - val_accuracy: 0.7093 - val_loss: 0.5414
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6795 - loss: 0.5532 - val_accuracy: 0.7326 - val_loss: 0.5512
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7121 - loss: 0.5466 - val_accuracy: 0.6919 - val_loss: 0.5214
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7238 - loss: 0.5492 - val_accuracy: 0.6919 - val_loss: 0.5293
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.6949 - loss: 0.5584 - val_accuracy: 0.7093 - val_loss: 0.5203
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6817 - loss: 0.5508 - val_accuracy: 0.7267 - val_loss: 0.5342
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7137 - loss: 0.5577 - val_accuracy: 0.7093 - val_loss: 0.5155
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7115 - loss: 0.5540 - val_accuracy: 0.7035 - val_loss: 0.5402
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7323 - loss: 0.5247 - val_accuracy: 0.7384 - val_loss: 0.5303
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7154 - loss: 0.5400 - val_accuracy: 0.6977 - val_loss: 0.5994
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7003 - loss: 0.5519 - val_accuracy: 0.6279 - val_loss: 0.5581
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7153 - loss: 0.5398 - val_accuracy: 0.7791 - val_loss: 0.4951
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7259 - loss: 0.5442 - val_accuracy: 0.6686 - val_loss: 0.5281
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7143 - loss: 0.5329 - val_accuracy: 0.6337 - val_loss: 0.5574
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7346 - loss: 0.5332 - val_accuracy: 0.6744 - val_loss: 0.5506
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7541 - loss: 0.5149 - val_accuracy: 0.7209 - val_loss: 0.5112
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7798 - loss: 0.4810 - val_accuracy: 0.7209 - val_loss: 0.5424
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7781 - loss: 0.5024 - val_accuracy: 0.7558 - val_loss: 0.4898
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7560 - loss: 0.5073 - val_accuracy: 0.7907 - val_loss: 0.5248
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7649 - loss: 0.5018 - val_accuracy: 0.7442 - val_loss: 0.4811
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7792 - loss: 0.4820 - val_accuracy: 0.6744 - val_loss: 0.4851
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.7609 - loss: 0.5037 - val_accuracy: 0.8081 - val_loss: 0.4611
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8045 - loss: 0.4632 - val_accuracy: 0.7442 - val_loss: 0.4647
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8000 - loss: 0.4544 - val_accuracy: 0.7791 - val_loss: 0.4784
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8098 - loss: 0.4319 - val_accuracy: 0.8081 - val_loss: 0.4414
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8126 - loss: 0.4358 - val_accuracy: 0.8430 - val_loss: 0.3966
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8296 - loss: 0.4257 - val_accuracy: 0.8198 - val_loss: 0.3905
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8356 - loss: 0.4106 - val_accuracy: 0.8198 - val_loss: 0.4216
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8106 - loss: 0.4176 - val_accuracy: 0.8256 - val_loss: 0.4044
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8158 - loss: 0.4145 - val_accuracy: 0.8198 - val_loss: 0.3890
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8175 - loss: 0.4048 - val_accuracy: 0.8547 - val_loss: 0.3559
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8303 - loss: 0.3963 - val_accuracy: 0.8198 - val_loss: 0.3826
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8259 - loss: 0.4118 - val_accuracy: 0.8430 - val_loss: 0.3493
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8270 - loss: 0.3898 - val_accuracy: 0.8314 - val_loss: 0.3828
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8261 - loss: 0.3835 - val_accuracy: 0.6860 - val_loss: 0.5968
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8148 - loss: 0.4061 - val_accuracy: 0.8605 - val_loss: 0.3386
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8531 - loss: 0.3608 - val_accuracy: 0.8372 - val_loss: 0.3612
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8295 - loss: 0.3697 - val_accuracy: 0.8314 - val_loss: 0.3479
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.8342 - loss: 0.3686 - val_accuracy: 0.8430 - val_loss: 0.3463
# Epoch 66/100
#  9/22 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.8293 - loss: 0.3733

# %%
# Visualizar el progreso del entrenamiento
plot_training_history(history)

# %% [markdown]
# ## Testing

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_curve, auc,
    precision_recall_curve, average_precision_score
)

# %%
def comprehensive_model_evaluation(model, X_test, y_test, test_names, num_samples=10, plot_metrics=True):
    """
    Evaluación completa del modelo con todas las métricas típicas

    Args:
        model: Modelo entrenado
        X_test: Datos de prueba
        y_test: Etiquetas verdaderas (one-hot encoded)
        test_names: Nombres de las muestras
        num_samples: Número de predicciones individuales a mostrar
        plot_metrics: Si mostrar los gráficos

    Returns:
        dict: Diccionario con todas las métricas
    """

    # Hacer predicciones
    predictions = model.predict(X_test)
    predicted_classes = np.argmax(predictions, axis=1)

    # Convertir y_test de one-hot a índices de clase
    if len(y_test.shape) > 1 and y_test.shape[1] > 1:
        true_classes = np.argmax(y_test, axis=1)
    else:
        true_classes = y_test

    class_names = ['Non-Strident', 'Strident']

    '''
    # ========================
    # PREDICCIONES DE MUESTRA
    # ========================
    print("🔍 PREDICCIONES DE MUESTRA")
    print("=" * 60)

    for i in range(min(num_samples, len(X_test))):
        true_class = class_names[true_classes[i]]
        pred_class = class_names[predicted_classes[i]]
        confidence = np.max(predictions[i]) * 100

        status = "✅" if true_classes[i] == predicted_classes[i] else "❌"
        print(f"{status} {test_names[i]}: True: {true_class}, Predicted: {pred_class} ({confidence:.1f}%)")
    '''

    # ========================
    # MÉTRICAS BÁSICAS
    # ========================
    print(f"\n📊 MÉTRICAS DE EVALUACIÓN")
    print("=" * 60)

    # Calcular métricas
    accuracy = accuracy_score(true_classes, predicted_classes)
    precision = precision_score(true_classes, predicted_classes, average='weighted')
    recall = recall_score(true_classes, predicted_classes, average='weighted')
    f1 = f1_score(true_classes, predicted_classes, average='weighted')

    # Métricas por clase
    precision_per_class = precision_score(true_classes, predicted_classes, average=None)
    recall_per_class = recall_score(true_classes, predicted_classes, average=None)
    f1_per_class = f1_score(true_classes, predicted_classes, average=None)

    print(f"🎯 Accuracy (Exactitud): {accuracy:.4f} ({accuracy*100:.2f}%)")
    print(f"🎯 Precision (Precisión): {precision:.4f}")
    print(f"🎯 Recall (Sensibilidad): {recall:.4f}")
    print(f"🎯 F1-Score: {f1:.4f}")

    print(f"\n📋 MÉTRICAS POR CLASE:")
    print("=" * 60)
    for i, class_name in enumerate(class_names):
        print(f"  {class_name}:")
        print(f"    - Precision: {precision_per_class[i]:.4f}")
        print(f"    - Recall: {recall_per_class[i]:.4f}")
        print(f"    - F1-Score: {f1_per_class[i]:.4f}")

    # ========================
    # MATRIZ DE CONFUSIÓN
    # ========================
    cm = confusion_matrix(true_classes, predicted_classes)

    print(f"\n🔄 MATRIZ DE CONFUSIÓN:")
    print("=" * 60)
    t = ""
    print(f"{t:>16}",end="")
    for name in class_names:
        print(f"{name:>16}", end="")
    print()

    for i, true_name in enumerate(class_names):
        print(f"{true_name:>16}", end="")
        for j in range(len(class_names)):
            print(f"{cm[i,j]:>16}", end="")
        print()

    # Calcular métricas adicionales de la matriz de confusión
    if len(class_names) == 2:  # Para clasificación binaria
        tn, fp, fn, tp = cm.ravel()

        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0

        print(f"\n📈 MÉTRICAS ADICIONALES (Clasificación Binaria):")
        print("=" * 60)
        print(f"  True Positives (TP): {tp}")
        print(f"  True Negatives (TN): {tn}")
        print(f"  False Positives (FP): {fp}")
        print(f"  False Negatives (FN): {fn}")
        print(f"  Specificity (Especificidad): {specificity:.4f}")
        print(f"  Sensitivity (Sensibilidad): {sensitivity:.4f}")

    # ========================
    # REPORTE DE CLASIFICACIÓN
    # ========================
    print(f"\n📝 REPORTE DETALLADO DE CLASIFICACIÓN:")
    print("=" * 60)
    print(classification_report(true_classes, predicted_classes, target_names=class_names))

    # ========================
    # GRÁFICOS
    # ========================
    if plot_metrics:
        fig, axes = plt.subplots(2, 2, figsize=(15, 12))
        fig.suptitle('Métricas de Evaluación del Modelo', fontsize=16, fontweight='bold')

        # 1. Matriz de Confusión
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=class_names, yticklabels=class_names, ax=axes[0,0])
        axes[0,0].set_title('Matriz de Confusión')
        axes[0,0].set_xlabel('Predicción')
        axes[0,0].set_ylabel('Valor Real')

        # 2. Métricas por clase
        metrics_data = {
            'Precision': precision_per_class,
            'Recall': recall_per_class,
            'F1-Score': f1_per_class
        }

        x = np.arange(len(class_names))
        width = 0.25

        for i, (metric_name, values) in enumerate(metrics_data.items()):
            axes[0,1].bar(x + i*width, values, width, label=metric_name)

        axes[0,1].set_xlabel('Clases')
        axes[0,1].set_ylabel('Puntuación')
        axes[0,1].set_title('Métricas por Clase')
        axes[0,1].set_xticks(x + width)
        axes[0,1].set_xticklabels(class_names)
        axes[0,1].legend()
        axes[0,1].set_ylim(0, 1.1)

        # 3. Distribución de Confianza de Predicciones
        confidence_scores = np.max(predictions, axis=1)
        correct_predictions = (true_classes == predicted_classes)

        axes[1,0].hist(confidence_scores[correct_predictions], alpha=0.7,
                      label='Predicciones Correctas', bins=20, color='green')
        axes[1,0].hist(confidence_scores[~correct_predictions], alpha=0.7,
                      label='Predicciones Incorrectas', bins=20, color='red')
        axes[1,0].set_xlabel('Confianza de Predicción')
        axes[1,0].set_ylabel('Frecuencia')
        axes[1,0].set_title('Distribución de Confianza')
        axes[1,0].legend()

        # 4. ROC Curve (solo para clasificación binaria)
        if len(class_names) == 2:
            # Para ROC necesitamos las probabilidades de la clase positiva
            y_scores = predictions[:, 1]  # Probabilidades para clase 'Strident'
            fpr, tpr, _ = roc_curve(true_classes, y_scores)
            roc_auc = auc(fpr, tpr)

            axes[1,1].plot(fpr, tpr, color='darkorange', lw=2,
                          label=f'ROC curve (AUC = {roc_auc:.2f})')
            axes[1,1].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
            axes[1,1].set_xlim([0.0, 1.0])
            axes[1,1].set_ylim([0.0, 1.05])
            axes[1,1].set_xlabel('Tasa de Falsos Positivos')
            axes[1,1].set_ylabel('Tasa de Verdaderos Positivos')
            axes[1,1].set_title('Curva ROC')
            axes[1,1].legend(loc="lower right")
        else:
            # Para multiclase, mostrar accuracy por muestra
            sample_indices = range(min(50, len(X_test)))
            sample_accuracy = [1 if true_classes[i] == predicted_classes[i] else 0
                             for i in sample_indices]

            axes[1,1].plot(sample_indices, sample_accuracy, 'o-', alpha=0.7)
            axes[1,1].set_xlabel('Índice de Muestra')
            axes[1,1].set_ylabel('Predicción Correcta (1) / Incorrecta (0)')
            axes[1,1].set_title('Precisión por Muestra (primeras 50)')
            axes[1,1].set_ylim(-0.1, 1.1)

        plt.tight_layout()
        plt.show()

    # ========================
    # RETORNAR MÉTRICAS
    # ========================
    metrics_dict = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'precision_per_class': precision_per_class,
        'recall_per_class': recall_per_class,
        'f1_per_class': f1_per_class,
        'confusion_matrix': cm,
        'predictions': predictions,
        'predicted_classes': predicted_classes,
        'true_classes': true_classes,
        'confidence_scores': np.max(predictions, axis=1)
    }

    if len(class_names) == 2:
        # Añadir métricas específicas para clasificación binaria
        tn, fp, fn, tp = cm.ravel()
        metrics_dict.update({
            'true_positives': tp,
            'true_negatives': tn,
            'false_positives': fp,
            'false_negatives': fn,
            'specificity': tn / (tn + fp) if (tn + fp) > 0 else 0,
            'sensitivity': tp / (tp + fn) if (tp + fn) > 0 else 0,
            'roc_auc': auc(fpr, tpr) if 'fpr' in locals() else None
        })

    return metrics_dict

# %%
# Ver predicciones en el conjunto de prueba
metrics = comprehensive_model_evaluation(model, X_test, y_test, test_names)

# %%
# Guardar el modelo entrenado
# model.save('strident_classifier_model.h5')
