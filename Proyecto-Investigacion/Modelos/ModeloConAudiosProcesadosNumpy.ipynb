# %% [markdown]
# <a href="https://colab.research.google.com/github/24danielcr/inteligencia-artificial/blob/main/Proyecto-Investigacion/Modelos/ModeloConAudiosProcesadosNumpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clasificacion de sonidos estridentes con espectrogramas
#
# **Integrantes:**
# - Christopher Víquez Aguilar - christopherviquezaguilar@gmail.com
# - Sebastian Arce Flores - sebasarc0224@hotmail.com
# - Daniel Gómez Solís - daniel.gomezsolis@ucr.ac.cr
# - Francisco Ulate Alpízar - francisco.ulate@ucr.ac.cr

# %% [markdown]
# # Librerias y dependencias

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 1.4 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.8 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 63.8 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 22.4 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 97.1 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 110.3 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 117.9 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.9 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, google-pasta, tensorboard, astunparse, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.31.1
#     Uninstalling protobuf-6.31.1:
#       Successfully uninstalled protobuf-6.31.1
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 google-pasta-0.2.0 libclang-18.1.1 protobuf-5.29.5 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 werkzeug-3.1.3 wheel-0.45.1

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, GlobalAvgPool2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
import matplotlib.pyplot as plt
import random
import os
import glob
import requests
from collections import defaultdict

# %% [markdown]
# # Datos

# %% [markdown]
# ## Descarga de datos

# %%
def download_github_folder_recursive(owner, repo, folder_path, local_base_path, branch='main'):
    """
    Descarga recursivamente una carpeta completa de GitHub manteniendo la estructura
    """
    api_url = f"https://api.github.com/repos/{owner}/{repo}/contents/{folder_path}"

    try:
        response = requests.get(api_url)
        if response.status_code != 200:
            print(f"Error accessing {folder_path}: {response.status_code}")
            return

        items = response.json()

        # Crear directorio local si no existe
        local_folder_path = os.path.join(local_base_path, folder_path)
        os.makedirs(local_folder_path, exist_ok=True)

        for item in items:
            if item['type'] == 'file' and item['name'].endswith('.png'):
                # Descargar archivo
                file_url = f"https://raw.githubusercontent.com/{owner}/{repo}/{branch}/{folder_path}/{item['name']}"
                file_response = requests.get(file_url)

                if file_response.status_code == 200:
                    file_path = os.path.join(local_folder_path, item['name'])
                    with open(file_path, 'wb') as f:
                        f.write(file_response.content)
                    print(f"✓ Descargado: {folder_path}/{item['name']}")
                else:
                    print(f"✗ Error descargando: {folder_path}/{item['name']}")

            elif item['type'] == 'dir':
                # Llamada recursiva para subdirectorios
                subfolder_path = f"{folder_path}/{item['name']}" if folder_path else item['name']
                download_github_folder_recursive(owner, repo, subfolder_path, local_base_path, branch)

    except Exception as e:
        print(f"Error procesando {folder_path}: {str(e)}")

def download_sound_dataset_from_github(owner, repo, dataset_folder="Sounds-Processed", branch='main', local_path='/content'):
    """
    Descarga el dataset completo desde GitHub con la estructura:
    Sounds-Processed/
    ├── test/
    │   ├── Non-Strident/
    │   └── Strident/
    ├── train/
    │   ├── Non-Strident/
    │   └── Strident/
    └── val/
        ├── Non-Strident/
        └── Strident/
    """

    print(f"🔄 Descargando dataset desde GitHub: {owner}/{repo}")
    print(f"📁 Carpeta: {dataset_folder}")
    print("=" * 60)

    # Descargar toda la estructura recursivamente
    download_github_folder_recursive(owner, repo, dataset_folder, local_path, branch)

    print("\n✅ Descarga completada")
    return os.path.join(local_path, dataset_folder)

# %%
# Descargar datos desde GitHub
owner = "24danielcr"
repo = "inteligencia-artificial"
dataset_folder = "Proyecto-Investigacion/Sounds-Processed/cache"
branch = "main"

local_dataset_path = download_sound_dataset_from_github(owner, repo, dataset_folder, branch)
# Out:
# 🔄 Descargando dataset desde GitHub: 24danielcr/inteligencia-artificial
# 📁 Carpeta: Proyecto-Investigacion/Sounds-Processed/cache
# ============================================================
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/1-12654-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/17_11740.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/17_11757.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11835.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11839.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11841.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11861.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11863.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11867.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11870.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/18_11871.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/19_11940.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/19_11943.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/19_11951.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/19_11953.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/19_11966.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/1_10146.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/1_10171.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/2-125821-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/2-68595-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/2-72547-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/2-85139-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/23_12364.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/23_12371.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/27_12734.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/3-163607-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/3-164592-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4-163697-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4-171823-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4-187769-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4-216211-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4_10438.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4_10440.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4_10444.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4_10449.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/4_10450.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/5-257839-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/6_10637.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/6_10653.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0human140140_43-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0human162024_43-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0human179928_3223507-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0human193794_2580450-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0human55495_36188-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0human77372_1173265-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0human80280_1123190-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0mechanical145013_2580450-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0mechanical169167_2826383-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0mechanical204001_3816115-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0mechanical53482_215874-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature107823_1754537-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature110575_28867-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature122617_2462-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature130459_1565498-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature45138_283424-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature46904_529006-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature54595_18799-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature59247_745228-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature62281_29541-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature65487_882296-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature67237_949430-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature69648_634166-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0nature83961_646701-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society14468_36042-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society148889_280284-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society164344_18799-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society169230_1648170-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society204364_3279490-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society22726_117199-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society35299_341440-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society62633_791247-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Non-Strident/r_0society73610_649002-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-101296-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-172649-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-187207-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-211527-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-22694-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-23996-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-24076-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-254507-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-26176-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-28808-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-34119-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-39835-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-47714-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-76831-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-76831-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-79236-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-84536-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-88807-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/1-977-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-100786-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-102568-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-104105-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-105270-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-109231-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-109371-D.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-114280-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-118104-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-118964-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-151079-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-184077-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-188822-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-188822-D.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-50666-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-68391-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-71162-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-78562-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-81731-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-91912-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-91912-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/2-93030-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-118658-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-129264-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-134049-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-136451-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-136608-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-141559-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-142005-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-143562-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-144827-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-144891-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-145577-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-159348-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-180977-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-203377-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-51731-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-51909-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-97909-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/3-98193-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-107120-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-121532-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-144083-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-147658-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-150364-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-159426-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-163608-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-163609-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-164206-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-167063-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-172736-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-175000-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-175846-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-182613-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-185575-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-191687-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-198360-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-204777-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-251645-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/4-59579-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/436572__magicthighs__corella-screech-x2.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-117122-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-161270-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-171653-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-177957-D.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-179496-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-179496-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-194930-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-198373-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-198411-F.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-201274-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-207811-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-208810-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-210612-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-217186-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-217186-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-220955-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-222041-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-233607-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-235893-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-250258-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/test/Strident/5-253101-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-12653-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-12654-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-16746-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-23094-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-23094-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-34497-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-38559-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-38560-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-50623-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-54918-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-54918-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-57316-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-57318-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-59102-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-7456-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-80840-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-80841-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1-90797-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11736.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11737.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11738.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11739.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11741.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11742.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11743.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11744.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11745.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11746.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11747.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11748.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11749.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11750.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11751.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11752.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11753.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11754.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11756.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11758.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11760.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11761.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11762.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11763.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11764.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11765.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11766.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11767.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11768.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11769.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11770.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11771.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11772.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11773.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11774.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/17_11775.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11836.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11837.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11838.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11840.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11842.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11843.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11844.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11845.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11846.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11847.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11849.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11850.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11853.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11854.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11855.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11856.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11857.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11858.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11859.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11864.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11865.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11866.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11868.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11869.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11872.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11873.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/18_11874.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11935.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11936.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11937.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11938.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11939.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11941.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11944.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11945.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11946.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11947.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11948.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11949.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11950.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11952.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11954.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11955.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11956.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11957.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11958.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11959.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11961.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11962.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11963.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11964.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11965.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11967.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11968.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11969.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11970.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11971.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11972.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11973.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/19_11974.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10136.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10137.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10138.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10139.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10140.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10141.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10142.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10143.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10144.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10145.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10147.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10148.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10149.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10150.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10151.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10152.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10154.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10156.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10157.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10159.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10160.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10161.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10162.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10163.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10164.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10165.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10166.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10167.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10169.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10170.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10172.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10173.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/1_10175.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-106019-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-108760-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-108760-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-108761-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-122616-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-124564-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-125875-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-139748-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-139748-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-139749-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-64962-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-64963-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-68595-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-72547-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-72547-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-72547-D.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/2-96033-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12351.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12352.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12353.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12354.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12355.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12356.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12358.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12363.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12366.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12367.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12368.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12370.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12372.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/23_12373.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12713.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12714.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12717.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12727.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12739.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12740.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12745.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12748.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12749.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12750.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12751.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12759.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12760.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12761.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12762.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12763.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12764.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12765.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12766.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12770.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/27_12772.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-129338-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-134802-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-146033-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-155577-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-155578-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-155579-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-155583-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-155584-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-156581-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-156581-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-156907-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-160119-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-162786-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-163607-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-164593-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-164594-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-166324-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/3-181132-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-159609-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-159609-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-168155-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-172143-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-174797-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-181362-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-182795-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-187769-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-188293-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-188293-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-194246-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-195707-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-195805-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-197871-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-212604-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-212604-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-223125-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4-223127-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10439.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10441.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10442.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10443.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10445.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10447.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10448.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10451.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10452.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10453.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10454.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10455.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10456.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10457.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10458.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10459.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10461.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10462.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10463.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10464.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10465.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10467.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10468.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10469.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10470.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10471.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10472.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10473.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10474.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/4_10475.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-204352-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-204352-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-210540-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-215172-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-215179-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-216213-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-216214-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-216216-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-241846-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-242490-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-243448-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-243449-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-243450-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-243459-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-243459-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-254832-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-254832-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-257349-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-261433-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/5-262641-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10635.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10636.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10639.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10640.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10641.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10643.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10645.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10646.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10648.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10650.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10651.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10652.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10654.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10655.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10656.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10657.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10658.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10659.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10660.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10661.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10663.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10666.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10667.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10668.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10669.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10670.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10671.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10672.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10673.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10674.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/6_10675.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human101979_1313063-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human102617_425689-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human106261_1707984-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human106568_7037-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human113598_1015240-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human115208_1143716-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human117503_2101324-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human118096_29541-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human125859_43-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human127590_1648170-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human128097_2338419-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human128768_806506-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human129783_1188483-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human138091_1839281-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human143651_1924005-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human144024_2588050-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human147543_591423-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human147643_2587501-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human151060_2400359-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human156040_2558789-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human156847_2730748-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human161417_2895542-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human162620_2111976-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Non-Strident/r_0human166175_1773681-hq.png
# ...
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/train/Strident/4-147657-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1-100038-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1-34495-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1-46040-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1-65483-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1-9841-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/17_11755.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/17_11759.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/18_11848.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/18_11851.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/18_11852.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/18_11860.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/18_11862.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/19_11942.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/19_11960.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1_10153.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1_10155.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1_10158.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1_10168.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/1_10174.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/2-110613-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/2-80844-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/2-83270-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/23_12357.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/23_12365.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/27_12728.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/3-129678-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/3-155766-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/3-164595-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/3-166326-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/4-202749-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/4-212604-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/4_10436.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/4_10437.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/4_10446.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/4_10460.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/4_10466.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/5-242491-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/5-259180-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/5-261439-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10638.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10642.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10644.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10647.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10649.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10662.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10664.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/6_10665.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0human150850_826206-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0human171120_2140699-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0human52285_626078-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0human60482_719027-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0human73108_36188-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0human76849_7037-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0mechanical171951_114198-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0mechanical2356_3525-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0mechanical239939_3597870-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0mechanical262587_4206277-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0mechanical264313_3820822-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0mechanical318619_739478-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0mechanical94285_1499659-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0nature101325_99904-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0nature139945_2352202-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0nature149223_221578-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0society121787_2168040-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0society122738_2140699-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0society152038_2753909-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0society42368_215874-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0society46732_26695-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0society80258_1123190-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_0society95843_1059930-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_1mechanical163683_2843367-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Non-Strident/r_4mechanical264850_4975383-hq.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-100032-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-101296-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-119125-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-160563-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-181071-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-19898-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-32373-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-34853-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-43382-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-43807-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-46744-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-51035-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-51036-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-51805-D.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-56907-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-60460-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-64398-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-76831-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-96890-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/1-96950-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-102567-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-108767-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-108767-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-109231-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-109371-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-112213-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-116400-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-117330-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-119102-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-122104-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-123712-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-128631-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-141681-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-141682-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-144137-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-188822-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-37806-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-50668-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-54086-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-60180-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-70366-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-70936-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-78381-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-80313-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-82538-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-87780-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-87781-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/2-96654-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-103051-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-122110-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-138212-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-149189-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-150231-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-151269-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-155642-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-165856-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-243726-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/3-94355-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/382586__macdaddyno1__eerie-sounding-train-with-a-breaking-screech.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-102871-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-108352-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-111671-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-119647-D.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-125929-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-132839-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-144083-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-156827-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-156844-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-156993-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-157297-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-160036-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-161103-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-163606-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-165823-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-165845-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-168446-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-169127-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-172734-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-184237-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-185575-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-194754-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-218199-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/4-218199-H.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-133989-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-156999-C.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-160551-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-170338-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-184323-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-187444-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-188365-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-192191-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-199284-B.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-201170-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-213855-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-219379-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-221529-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-233312-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-234879-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/5-236288-A.png
# ✓ Descargado: Proyecto-Investigacion/Sounds-Processed/cache/val/Strident/752837__lukacafuka__distant-car-tire-screeching.png
#
# ✅ Descarga completada

# %% [markdown]
# ## Carga del dataset

# %%
def load_dataset_structure(base_path):
    """Carga todos los archivos PNG organizados por conjunto y clase"""
    dataset = {
        'train': {'Non-Strident': [], 'Strident': []},
        'test': {'Non-Strident': [], 'Strident': []},
        'val': {'Non-Strident': [], 'Strident': []}
    }

    print("📊 Organizando archivos PNG del dataset...")
    print("=" * 40)

    total_files = 0

    for split in ['train', 'test', 'val']:
        for class_name in ['Non-Strident', 'Strident']:
            path = os.path.join(base_path, split, class_name)
            if os.path.exists(path):
                # Buscar específicamente archivos .png
                png_files = glob.glob(os.path.join(path, '*.png'))
                dataset[split][class_name] = png_files
                total_files += len(png_files)
                print(f"🖼️  {split}/{class_name}: {len(png_files)} imágenes PNG")
            else:
                print(f"⚠️  {split}/{class_name}: Carpeta no encontrada")

    print(f"\n🎯 Total de imágenes PNG cargadas: {total_files}")
    return dataset

def get_dataset_summary(dataset):
    """Muestra un resumen del dataset cargado"""
    print("\n📈 RESUMEN DEL DATASET")
    print("=" * 50)

    for split in ['train', 'test', 'val']:
        total_split = sum(len(files) for files in dataset[split].values())
        non_strident_count = len(dataset[split]['Non-Strident'])
        strident_count = len(dataset[split]['Strident'])

        print(f"\n{split.upper()}:")
        print(f"  • Total: {total_split} archivos")
        print(f"  • Non-Strident: {non_strident_count}")
        print(f"  • Strident: {strident_count}")

        if total_split > 0:
            balance = min(non_strident_count, strident_count) / max(non_strident_count, strident_count) * 100
            print(f"  • Balance de clases: {balance:.1f}%")

def load_and_display_sample_images(dataset, split='train', samples_per_class=3):
    """
    Carga y muestra imágenes de muestra del dataset
    """
    import matplotlib.pyplot as plt
    from PIL import Image

    fig, axes = plt.subplots(2, samples_per_class, figsize=(15, 8))
    fig.suptitle(f'Muestras del conjunto {split.upper()}', fontsize=16)

    classes = ['Non-Strident', 'Strident']

    for i, class_name in enumerate(classes):
        images = dataset[split][class_name][:samples_per_class]

        for j, img_path in enumerate(images):
            try:
                img = Image.open(img_path)
                axes[i, j].imshow(img)
                axes[i, j].set_title(f'{class_name}\n{os.path.basename(img_path)}')
                axes[i, j].axis('off')
            except Exception as e:
                axes[i, j].text(0.5, 0.5, f'Error:\n{str(e)}',
                               ha='center', va='center', transform=axes[i, j].transAxes)
                axes[i, j].axis('off')

    plt.tight_layout()
    plt.show()

def get_image_info(dataset):
    """
    Obtiene información sobre las dimensiones de las imágenes
    """
    from PIL import Image

    print("🖼️  INFORMACIÓN DE IMÁGENES")
    print("=" * 50)

    for split in ['train', 'test', 'val']:
        print(f"\n{split.upper()}:")

        for class_name in ['Non-Strident', 'Strident']:
            images = dataset[split][class_name]
            if images:
                # Tomar una muestra para analizar dimensiones
                sample_size = min(5, len(images))
                dimensions = []

                for img_path in images[:sample_size]:
                    try:
                        with Image.open(img_path) as img:
                            dimensions.append(img.size)  # (width, height)
                    except:
                        continue

                if dimensions:
                    widths = [d[0] for d in dimensions]
                    heights = [d[1] for d in dimensions]

                    print(f"  {class_name}:")
                    print(f"    • Archivos: {len(images)}")
                    print(f"    • Dimensiones promedio: {sum(widths)//len(widths)}x{sum(heights)//len(heights)}")
                    print(f"    • Rango ancho: {min(widths)}-{max(widths)}px")
                    print(f"    • Rango alto: {min(heights)}-{max(heights)}px")

# %%
# Organizar archivos
local_dataset_path = "Proyecto-Investigacion/Sounds-Processed/cache"
dataset = load_dataset_structure(local_dataset_path)
# Out:
# 📊 Organizando archivos PNG del dataset...
# ========================================
# 🖼️  train/Non-Strident: 499 imágenes PNG
# 🖼️  train/Strident: 500 imágenes PNG
# 🖼️  test/Non-Strident: 72 imágenes PNG
# 🖼️  test/Strident: 100 imágenes PNG
# 🖼️  val/Non-Strident: 72 imágenes PNG
# 🖼️  val/Strident: 100 imágenes PNG
#
# 🎯 Total de imágenes PNG cargadas: 1343

# %%
# Mostrar resumen
get_dataset_summary(dataset)
# Out:
# 📈 RESUMEN DEL DATASET
# ==================================================
#
# TRAIN:
#   • Total: 999 archivos
#   • Non-Strident: 499
#   • Strident: 500
#   • Balance de clases: 99.8%
#
# TEST:
#   • Total: 172 archivos
#   • Non-Strident: 72
#   • Strident: 100
#   • Balance de clases: 72.0%
#
# VAL:
#   • Total: 172 archivos
#   • Non-Strident: 72
#   • Strident: 100
#   • Balance de clases: 72.0%

# %%
# Ver información de las imágenes
get_image_info(dataset)
# Out:
# 🖼️  INFORMACIÓN DE IMÁGENES
# ==================================================
#
# TRAIN:
#   Non-Strident:
#     • Archivos: 499
#     • Dimensiones promedio: 345x128
#     • Rango ancho: 345-345px
#     • Rango alto: 128-128px
#   Strident:
#     • Archivos: 500
#     • Dimensiones promedio: 345x128
#     • Rango ancho: 345-345px
#     • Rango alto: 128-128px
#
# TEST:
#   Non-Strident:
#     • Archivos: 72
#     • Dimensiones promedio: 345x128
#     • Rango ancho: 345-345px
#     • Rango alto: 128-128px
#   Strident:
#     • Archivos: 100
#     • Dimensiones promedio: 345x128
#     • Rango ancho: 345-345px
#     • Rango alto: 128-128px
#
# VAL:
#   Non-Strident:
#     • Archivos: 72
#     • Dimensiones promedio: 345x128
#     • Rango ancho: 345-345px
#     • Rango alto: 128-128px
#   Strident:
#     • Archivos: 100
#     • Dimensiones promedio: 345x128
#     • Rango ancho: 345-345px
#     • Rango alto: 128-128px

# %%
# Mostrar imágenes de muestra
load_and_display_sample_images(dataset, split='train', samples_per_class=3)

# %% [markdown]
# ## Preprocess dataset

# %%
def load_images_as_arrays(dataset, split='train', max_per_class=None, target_size=(500, 200)):
    """
    Carga las imágenes como arrays de numpy para machine learning,
    redimensionando a un tamaño objetivo.
    """
    import numpy as np
    from PIL import Image

    X = []  # imágenes
    y = []  # etiquetas
    filenames = []

    classes = ['Non-Strident', 'Strident']

    print(f"Cargando imágenes del conjunto {split.upper()} y redimensionando a {target_size}...")

    for i, class_name in enumerate(classes):
        images = dataset[split][class_name]

        # if max_per_class:
        #     images = images[:max_per_class]

        print(f"  Cargando {len(images)} imágenes de {class_name}...")

        for img_path in images:
            try:
                # file = np.load(npy_path)
                # X.append(file)
                # y.append(i)  # 0 para Non-Strident, 1 para Strident
                # filenames.append(os.path.basename(npy_path))


                with Image.open(img_path) as img:
                    # Convertir a RGB si es necesario
                    if img.mode != 'RGB':
                        img = img.convert('RGB')

                    # Redimensionar imagen
                    # img_resized = img.resize(target_size)

                    # Convertir a array
                    img_array = np.array(img)

                    X.append(img_array)
                    y.append(i)  # 0 para Non-Strident, 1 para Strident
                    filenames.append(os.path.basename(img_path))

            except Exception as e:
                print(f"Error cargando {img_path}: {e}")

    X = np.array(X)
    y = np.array(y)

    print(f"✅ Cargadas {len(X)} imágenes con forma {X.shape}")
    return X, y, filenames

# %%
# 5. Cargar imágenes como arrays para machine learning
X_train, y_train, train_names = load_images_as_arrays(dataset, 'train')
X_test, y_test, test_names = load_images_as_arrays(dataset, 'test')
X_val, y_val, val_names = load_images_as_arrays(dataset, 'val')

print(f"Forma de datos de entrenamiento: {X_train.shape}")
print(f"Etiquetas de entrenamiento: {y_train.shape}")
print(f"Forma de datos de prueba: {X_test.shape}")
print(f"Etiquetas de prueba: {y_test.shape}")
# Out:
# Cargando imágenes del conjunto TRAIN y redimensionando a (500, 200)...
#   Cargando 499 imágenes de Non-Strident...
#   Cargando 500 imágenes de Strident...
# ✅ Cargadas 999 imágenes con forma (999, 128, 345, 3)
# Cargando imágenes del conjunto TEST y redimensionando a (500, 200)...
#   Cargando 72 imágenes de Non-Strident...
#   Cargando 100 imágenes de Strident...
# ✅ Cargadas 172 imágenes con forma (172, 128, 345, 3)
# Cargando imágenes del conjunto VAL y redimensionando a (500, 200)...
#   Cargando 72 imágenes de Non-Strident...
#   Cargando 100 imágenes de Strident...
# ✅ Cargadas 172 imágenes con forma (172, 128, 345, 3)
# Forma de datos de entrenamiento: (999, 128, 345, 3)
# Etiquetas de entrenamiento: (999,)
# Forma de datos de prueba: (172, 128, 345, 3)
# Etiquetas de prueba: (172,)

# %%
# 2. PREPROCESAMIENTO DE DATOS
def preprocess_data(X_train, X_test, X_val):
    """
    Preprocesa los datos para entrenamiento
    """
    print("🔧 Preprocesando datos...")

    # Normalizar píxeles (0-255 -> 0-1) - This is likely not needed for .npy data that is not image pixel values
    X_train = X_train.astype('float32') / 255.0
    X_test = X_test.astype('float32') / 255.0
    X_val = X_val.astype('float32') / 255.0

    # Add a channel dimension (for grayscale, this is 1)
    # X_train = np.expand_dims(X_train, axis=-1)
    # X_test = np.expand_dims(X_test, axis=-1)
    # X_val = np.expand_dims(X_val, axis=-1)


    print(f"✅ Datos preprocesados:")
    print(f"   Training: {X_train.shape}")
    print(f"   Test: {X_test.shape}")
    print(f"   Validation: {X_val.shape}")

    return X_train, X_test, X_val

# %%
X_train, X_test, X_val = preprocess_data(X_train, X_test, X_val) # Solo usar si son pngs no cuando son .npy
# Out:
# 🔧 Preprocesando datos...
# ✅ Datos preprocesados:
#    Training: (999, 128, 345, 3)
#    Test: (172, 128, 345, 3)
#    Validation: (172, 128, 345, 3)

# %%
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)

print(f"Forma de etiquetas de entrenamiento: {y_train.shape}")
print(f"Forma de etiquetas de prueba: {y_test.shape}")
print(f"Forma de etiquetas de validación: {y_val.shape}")
# Out:
# Forma de etiquetas de entrenamiento: (999, 2)
# Forma de etiquetas de prueba: (172, 2)
# Forma de etiquetas de validación: (172, 2)

# %% [markdown]
# # CNN model

# %% [markdown]
# ## Arquitectura

# %%
# CREAR EL MODELO (con input_shape correcto)
def create_cnn_model(input_shape):
    """
    Crea el modelo CNN con la forma de entrada correcta
    """
    print(f"🏗️  Creando modelo CNN con input_shape: {input_shape}")

    model = Sequential()

    # Primera capa convolucional
    model.add(Conv2D(16, (3, 3), activation='relu', input_shape=input_shape))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

    # Segunda capa convolucional
    model.add(Conv2D(32, (3, 3), activation='relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

    # Tercera capa convolucional
    model.add(Conv2D(64, (3, 3), activation='relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

    # Pooling
    model.add(GlobalAvgPool2D())
    #model.add(Dropout(0.25))

    # Capas densas
    #model.add(Flatten())
    #model.add(Dense(128, activation='relu'))
    #model.add(BatchNormalization())
    #model.add(Dropout(0.5))

    model.add(Dense(64, activation='relu'))

    # Salida
    model.add(Dense(2, activation='softmax'))  # 2 clases: Non-Strident y Strident

    # Compilar modelo
    model.compile(
        loss='categorical_crossentropy',
        optimizer='rmsprop',
        metrics=['accuracy']
    )

    return model

# %%
input_shape = X_train.shape[1:]

model = create_cnn_model(input_shape)

# Mostrar resumen del modelo
print("\n📋 Resumen del modelo:")
model.summary()
# Out:
# 🏗️  Creando modelo CNN con input_shape: (128, 345, 3)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 📋 Resumen del modelo:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_19 (Conv2D)              │ (None, 126, 343, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 63, 171, 16)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 61, 169, 32)    │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 30, 84, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 28, 82, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 14, 41, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,874 (108.88 KB)
#  Trainable params: 27,874 (108.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training

# %%
# CONFIGURAR CALLBACKS
def setup_callbacks():
    """
    Configura los callbacks para el entrenamiento
    """
    earlystop = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    learning_rate_reduction = ReduceLROnPlateau(
        monitor='val_accuracy',  # Cambiado de 'val_acc' a 'val_accuracy'
        patience=3,
        verbose=1,
        factor=0.5,
        min_lr=0.00001
    )

    return [earlystop] # [earlystop, learning_rate_reduction]

# FUNCIÓN PRINCIPAL DE ENTRENAMIENTO
def train_model(model, X_train, y_train, X_val, y_val,
                epochs=50, batch_size=32, verbose=1):
    """
    Entrena el modelo CNN completo
    """
    print("🚀 Iniciando entrenamiento del modelo...")
    print("=" * 60)

    # Configurar callbacks
    callbacks = setup_callbacks()

    # Add print statements to check shapes
    print(f"Shape of X_train before fit: {X_train.shape}")
    print(f"Shape of y_train before fit: {y_train.shape}")
    print(f"Shape of X_val before fit: {X_val.shape}")
    print(f"Shape of y_val before fit: {y_val.shape}")


    # Entrenar modelo
    print(f"\n🎯 Entrenando por {epochs} épocas...")
    history = model.fit(
        X_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(X_val, y_val),
        callbacks=callbacks,
        verbose=verbose
    )

    # Evaluar en conjunto de prueba
    print("\n📊 Evaluando en conjunto de prueba...")
    test_loss, test_accuracy = model.evaluate(X_val, y_val, verbose=0)
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

    return history

# FUNCIÓN PARA VISUALIZAR RESULTADOS
def plot_training_history(history):
    """
    Visualiza la historia del entrenamiento
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # Accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)

    # Loss
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

# %%
# Entrenar el modelo (esto ejecutará todo el pipeline)
history = train_model(model, X_train, y_train, X_val, y_val,
                            epochs=100, batch_size=64)
# Out:
# 🚀 Iniciando entrenamiento del modelo...
# ============================================================
# Shape of X_train before fit: (999, 128, 345, 3)
# Shape of y_train before fit: (999, 2)
# Shape of X_val before fit: (172, 128, 345, 3)
# Shape of y_val before fit: (172, 2)
#
# 🎯 Entrenando por 100 épocas...
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4985 - loss: 0.6962 - val_accuracy: 0.5814 - val_loss: 0.6903
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.4906 - loss: 0.6939 - val_accuracy: 0.4186 - val_loss: 0.6941
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.4909 - loss: 0.6933 - val_accuracy: 0.4186 - val_loss: 0.6940
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.4958 - loss: 0.6931 - val_accuracy: 0.5814 - val_loss: 0.6886
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.5244 - loss: 0.6929 - val_accuracy: 0.4186 - val_loss: 0.6975
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5176 - loss: 0.6918 - val_accuracy: 0.5291 - val_loss: 0.6922
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5601 - loss: 0.6908 - val_accuracy: 0.4302 - val_loss: 0.6971
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.4919 - loss: 0.6914 - val_accuracy: 0.4360 - val_loss: 0.6981
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5477 - loss: 0.6867 - val_accuracy: 0.4186 - val_loss: 0.7786
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5533 - loss: 0.6926 - val_accuracy: 0.5523 - val_loss: 0.6814
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5847 - loss: 0.6816 - val_accuracy: 0.4186 - val_loss: 0.7232
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5503 - loss: 0.6844 - val_accuracy: 0.5000 - val_loss: 0.6963
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6006 - loss: 0.6695 - val_accuracy: 0.4186 - val_loss: 0.7496
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5601 - loss: 0.6787 - val_accuracy: 0.6105 - val_loss: 0.6768
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5586 - loss: 0.6826 - val_accuracy: 0.5640 - val_loss: 0.6721
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5944 - loss: 0.6731 - val_accuracy: 0.5523 - val_loss: 0.6835
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6093 - loss: 0.6689 - val_accuracy: 0.5465 - val_loss: 0.6803
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6155 - loss: 0.6646 - val_accuracy: 0.4244 - val_loss: 0.7345
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5870 - loss: 0.6631 - val_accuracy: 0.6163 - val_loss: 0.6525
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5733 - loss: 0.6748 - val_accuracy: 0.6453 - val_loss: 0.6510
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6025 - loss: 0.6606 - val_accuracy: 0.6047 - val_loss: 0.6689
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6059 - loss: 0.6626 - val_accuracy: 0.5988 - val_loss: 0.6660
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6625 - loss: 0.6495 - val_accuracy: 0.7267 - val_loss: 0.6280
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6419 - loss: 0.6443 - val_accuracy: 0.7093 - val_loss: 0.6368
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6447 - loss: 0.6442 - val_accuracy: 0.5814 - val_loss: 0.7003
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6393 - loss: 0.6526 - val_accuracy: 0.6337 - val_loss: 0.6498
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6434 - loss: 0.6535 - val_accuracy: 0.5698 - val_loss: 0.6658
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7039 - loss: 0.6256 - val_accuracy: 0.7500 - val_loss: 0.6029
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6969 - loss: 0.6105 - val_accuracy: 0.7384 - val_loss: 0.5980
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6915 - loss: 0.6094 - val_accuracy: 0.4302 - val_loss: 0.9073
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5947 - loss: 0.7000 - val_accuracy: 0.7326 - val_loss: 0.5900
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6777 - loss: 0.6142 - val_accuracy: 0.5174 - val_loss: 0.7285
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6593 - loss: 0.6328 - val_accuracy: 0.7151 - val_loss: 0.5871
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6925 - loss: 0.5986 - val_accuracy: 0.5000 - val_loss: 0.7262
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6579 - loss: 0.6314 - val_accuracy: 0.7326 - val_loss: 0.5788
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6829 - loss: 0.6115 - val_accuracy: 0.4186 - val_loss: 1.0511
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6766 - loss: 0.6538 - val_accuracy: 0.7442 - val_loss: 0.5641
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7310 - loss: 0.5818 - val_accuracy: 0.6279 - val_loss: 0.6510
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7156 - loss: 0.5876 - val_accuracy: 0.7384 - val_loss: 0.5596
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6946 - loss: 0.5936 - val_accuracy: 0.7035 - val_loss: 0.5908
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7415 - loss: 0.5786 - val_accuracy: 0.6860 - val_loss: 0.5719
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6824 - loss: 0.5885 - val_accuracy: 0.7384 - val_loss: 0.5531
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7220 - loss: 0.5691 - val_accuracy: 0.7209 - val_loss: 0.5525
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6911 - loss: 0.5837 - val_accuracy: 0.7500 - val_loss: 0.5451
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7096 - loss: 0.5878 - val_accuracy: 0.6744 - val_loss: 0.5807
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7065 - loss: 0.5697 - val_accuracy: 0.7384 - val_loss: 0.5288
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7228 - loss: 0.5734 - val_accuracy: 0.7674 - val_loss: 0.5337
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7211 - loss: 0.5771 - val_accuracy: 0.7151 - val_loss: 0.5454
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7362 - loss: 0.5516 - val_accuracy: 0.6686 - val_loss: 0.6052
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7064 - loss: 0.5790 - val_accuracy: 0.6919 - val_loss: 0.5758
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7417 - loss: 0.5456 - val_accuracy: 0.7384 - val_loss: 0.5456
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7309 - loss: 0.5468 - val_accuracy: 0.7733 - val_loss: 0.5141
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7345 - loss: 0.5504 - val_accuracy: 0.5465 - val_loss: 0.7194
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6807 - loss: 0.5785 - val_accuracy: 0.6279 - val_loss: 0.6665
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7291 - loss: 0.5636 - val_accuracy: 0.7791 - val_loss: 0.5047
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7556 - loss: 0.5352 - val_accuracy: 0.7791 - val_loss: 0.5062
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7531 - loss: 0.5281 - val_accuracy: 0.7442 - val_loss: 0.5263
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7526 - loss: 0.5275 - val_accuracy: 0.7674 - val_loss: 0.5151
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7379 - loss: 0.5350 - val_accuracy: 0.7209 - val_loss: 0.5425
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7298 - loss: 0.5673 - val_accuracy: 0.7093 - val_loss: 0.5451
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7246 - loss: 0.5627 - val_accuracy: 0.6337 - val_loss: 0.6585
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7024 - loss: 0.5717 - val_accuracy: 0.6860 - val_loss: 0.5996
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7122 - loss: 0.6272 - val_accuracy: 0.6570 - val_loss: 0.6345
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7431 - loss: 0.5571 - val_accuracy: 0.7384 - val_loss: 0.5311
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7553 - loss: 0.5277 - val_accuracy: 0.7384 - val_loss: 0.5247
# Epoch 65: early stopping
# Restoring model weights from the end of the best epoch: 55.
#
# 📊 Evaluando en conjunto de prueba...
# Test Loss: 0.5047
# Test Accuracy: 0.7791

# %%
# Visualizar el progreso del entrenamiento
plot_training_history(history)

# %% [markdown]
# ## Testing

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_curve, auc,
    precision_recall_curve, average_precision_score
)

# %%
def comprehensive_model_evaluation(model, X_test, y_test, test_names, num_samples=10, plot_metrics=True):
    """
    Evaluación completa del modelo con todas las métricas típicas

    Args:
        model: Modelo entrenado
        X_test: Datos de prueba
        y_test: Etiquetas verdaderas (one-hot encoded)
        test_names: Nombres de las muestras
        num_samples: Número de predicciones individuales a mostrar
        plot_metrics: Si mostrar los gráficos

    Returns:
        dict: Diccionario con todas las métricas
    """

    # Hacer predicciones
    predictions = model.predict(X_test)
    predicted_classes = np.argmax(predictions, axis=1)

    # Convertir y_test de one-hot a índices de clase
    if len(y_test.shape) > 1 and y_test.shape[1] > 1:
        true_classes = np.argmax(y_test, axis=1)
    else:
        true_classes = y_test

    class_names = ['Non-Strident', 'Strident']

    '''
    # ========================
    # PREDICCIONES DE MUESTRA
    # ========================
    print("🔍 PREDICCIONES DE MUESTRA")
    print("=" * 60)

    for i in range(min(num_samples, len(X_test))):
        true_class = class_names[true_classes[i]]
        pred_class = class_names[predicted_classes[i]]
        confidence = np.max(predictions[i]) * 100

        status = "✅" if true_classes[i] == predicted_classes[i] else "❌"
        print(f"{status} {test_names[i]}: True: {true_class}, Predicted: {pred_class} ({confidence:.1f}%)")
    '''

    # ========================
    # MÉTRICAS BÁSICAS
    # ========================
    print(f"\n📊 MÉTRICAS DE EVALUACIÓN")
    print("=" * 60)

    # Calcular métricas
    accuracy = accuracy_score(true_classes, predicted_classes)
    precision = precision_score(true_classes, predicted_classes, average='weighted')
    recall = recall_score(true_classes, predicted_classes, average='weighted')
    f1 = f1_score(true_classes, predicted_classes, average='weighted')

    # Métricas por clase
    precision_per_class = precision_score(true_classes, predicted_classes, average=None)
    recall_per_class = recall_score(true_classes, predicted_classes, average=None)
    f1_per_class = f1_score(true_classes, predicted_classes, average=None)

    print(f"🎯 Accuracy (Exactitud): {accuracy:.4f} ({accuracy*100:.2f}%)")
    print(f"🎯 Precision (Precisión): {precision:.4f}")
    print(f"🎯 Recall (Sensibilidad): {recall:.4f}")
    print(f"🎯 F1-Score: {f1:.4f}")

    print(f"\n📋 MÉTRICAS POR CLASE:")
    print("=" * 60)
    for i, class_name in enumerate(class_names):
        print(f"  {class_name}:")
        print(f"    - Precision: {precision_per_class[i]:.4f}")
        print(f"    - Recall: {recall_per_class[i]:.4f}")
        print(f"    - F1-Score: {f1_per_class[i]:.4f}")

    # ========================
    # MATRIZ DE CONFUSIÓN
    # ========================
    cm = confusion_matrix(true_classes, predicted_classes)

    print(f"\n🔄 MATRIZ DE CONFUSIÓN:")
    print("=" * 60)
    t = ""
    print(f"{t:>16}",end="")
    for name in class_names:
        print(f"{name:>16}", end="")
    print()

    for i, true_name in enumerate(class_names):
        print(f"{true_name:>16}", end="")
        for j in range(len(class_names)):
            print(f"{cm[i,j]:>16}", end="")
        print()

    # Calcular métricas adicionales de la matriz de confusión
    if len(class_names) == 2:  # Para clasificación binaria
        tn, fp, fn, tp = cm.ravel()

        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0

        print(f"\n📈 MÉTRICAS ADICIONALES (Clasificación Binaria):")
        print("=" * 60)
        print(f"  True Positives (TP): {tp}")
        print(f"  True Negatives (TN): {tn}")
        print(f"  False Positives (FP): {fp}")
        print(f"  False Negatives (FN): {fn}")
        print(f"  Specificity (Especificidad): {specificity:.4f}")
        print(f"  Sensitivity (Sensibilidad): {sensitivity:.4f}")

    # ========================
    # REPORTE DE CLASIFICACIÓN
    # ========================
    print(f"\n📝 REPORTE DETALLADO DE CLASIFICACIÓN:")
    print("=" * 60)
    print(classification_report(true_classes, predicted_classes, target_names=class_names))

    # ========================
    # GRÁFICOS
    # ========================
    if plot_metrics:
        fig, axes = plt.subplots(2, 2, figsize=(15, 12))
        fig.suptitle('Métricas de Evaluación del Modelo', fontsize=16, fontweight='bold')

        # 1. Matriz de Confusión
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=class_names, yticklabels=class_names, ax=axes[0,0])
        axes[0,0].set_title('Matriz de Confusión')
        axes[0,0].set_xlabel('Predicción')
        axes[0,0].set_ylabel('Valor Real')

        # 2. Métricas por clase
        metrics_data = {
            'Precision': precision_per_class,
            'Recall': recall_per_class,
            'F1-Score': f1_per_class
        }

        x = np.arange(len(class_names))
        width = 0.25

        for i, (metric_name, values) in enumerate(metrics_data.items()):
            axes[0,1].bar(x + i*width, values, width, label=metric_name)

        axes[0,1].set_xlabel('Clases')
        axes[0,1].set_ylabel('Puntuación')
        axes[0,1].set_title('Métricas por Clase')
        axes[0,1].set_xticks(x + width)
        axes[0,1].set_xticklabels(class_names)
        axes[0,1].legend()
        axes[0,1].set_ylim(0, 1.1)

        # 3. Distribución de Confianza de Predicciones
        confidence_scores = np.max(predictions, axis=1)
        correct_predictions = (true_classes == predicted_classes)

        axes[1,0].hist(confidence_scores[correct_predictions], alpha=0.7,
                      label='Predicciones Correctas', bins=20, color='green')
        axes[1,0].hist(confidence_scores[~correct_predictions], alpha=0.7,
                      label='Predicciones Incorrectas', bins=20, color='red')
        axes[1,0].set_xlabel('Confianza de Predicción')
        axes[1,0].set_ylabel('Frecuencia')
        axes[1,0].set_title('Distribución de Confianza')
        axes[1,0].legend()

        # 4. ROC Curve (solo para clasificación binaria)
        if len(class_names) == 2:
            # Para ROC necesitamos las probabilidades de la clase positiva
            y_scores = predictions[:, 1]  # Probabilidades para clase 'Strident'
            fpr, tpr, _ = roc_curve(true_classes, y_scores)
            roc_auc = auc(fpr, tpr)

            axes[1,1].plot(fpr, tpr, color='darkorange', lw=2,
                          label=f'ROC curve (AUC = {roc_auc:.2f})')
            axes[1,1].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
            axes[1,1].set_xlim([0.0, 1.0])
            axes[1,1].set_ylim([0.0, 1.05])
            axes[1,1].set_xlabel('Tasa de Falsos Positivos')
            axes[1,1].set_ylabel('Tasa de Verdaderos Positivos')
            axes[1,1].set_title('Curva ROC')
            axes[1,1].legend(loc="lower right")
        else:
            # Para multiclase, mostrar accuracy por muestra
            sample_indices = range(min(50, len(X_test)))
            sample_accuracy = [1 if true_classes[i] == predicted_classes[i] else 0
                             for i in sample_indices]

            axes[1,1].plot(sample_indices, sample_accuracy, 'o-', alpha=0.7)
            axes[1,1].set_xlabel('Índice de Muestra')
            axes[1,1].set_ylabel('Predicción Correcta (1) / Incorrecta (0)')
            axes[1,1].set_title('Precisión por Muestra (primeras 50)')
            axes[1,1].set_ylim(-0.1, 1.1)

        plt.tight_layout()
        plt.show()

    # ========================
    # RETORNAR MÉTRICAS
    # ========================
    metrics_dict = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'precision_per_class': precision_per_class,
        'recall_per_class': recall_per_class,
        'f1_per_class': f1_per_class,
        'confusion_matrix': cm,
        'predictions': predictions,
        'predicted_classes': predicted_classes,
        'true_classes': true_classes,
        'confidence_scores': np.max(predictions, axis=1)
    }

    if len(class_names) == 2:
        # Añadir métricas específicas para clasificación binaria
        tn, fp, fn, tp = cm.ravel()
        metrics_dict.update({
            'true_positives': tp,
            'true_negatives': tn,
            'false_positives': fp,
            'false_negatives': fn,
            'specificity': tn / (tn + fp) if (tn + fp) > 0 else 0,
            'sensitivity': tp / (tp + fn) if (tp + fn) > 0 else 0,
            'roc_auc': auc(fpr, tpr) if 'fpr' in locals() else None
        })

    return metrics_dict

# %%
# Ver predicciones en el conjunto de prueba
metrics = comprehensive_model_evaluation(model, X_test, y_test, test_names)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step
#
# 📊 MÉTRICAS DE EVALUACIÓN
# ============================================================
# 🎯 Accuracy (Exactitud): 0.7733 (77.33%)
# 🎯 Precision (Precisión): 0.7723
# 🎯 Recall (Sensibilidad): 0.7733
# 🎯 F1-Score: 0.7725
#
# 📋 MÉTRICAS POR CLASE:
# ============================================================
#   Non-Strident:
#     - Precision: 0.7391
#     - Recall: 0.7083
#     - F1-Score: 0.7234
#   Strident:
#     - Precision: 0.7961
#     - Recall: 0.8200
#     - F1-Score: 0.8079
#
# 🔄 MATRIZ DE CONFUSIÓN:
# ============================================================
#                     Non-Strident        Strident
#     Non-Strident              51              21
#         Strident              18              82
#
# 📈 MÉTRICAS ADICIONALES (Clasificación Binaria):
# ============================================================
#   True Positives (TP): 82
#   True Negatives (TN): 51
#   False Positives (FP): 21
#   False Negatives (FN): 18
#   Specificity (Especificidad): 0.7083
#   Sensitivity (Sensibilidad): 0.8200
#
# 📝 REPORTE DETALLADO DE CLASIFICACIÓN:
# ============================================================
#               precision    recall  f1-score   support
#
# Non-Strident       0.74      0.71      0.72        72
#     Strident       0.80      0.82      0.81       100
#
#     accuracy                           0.77       172
#    macro avg       0.77      0.76      0.77       172
# weighted avg       0.77      0.77      0.77       172

# %%
# Guardar el modelo entrenado
# model.save('strident_classifier_model.h5')
